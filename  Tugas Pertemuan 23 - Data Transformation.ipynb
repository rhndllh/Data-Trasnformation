# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/melb_data.csv', sep=';')
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG      Date Distance    Postcode  ...  Bathroom  Car   Landsize  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  object
#  9   Postcode       13580 non-null  object
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  object
#  14  BuildingArea   7130 non-null   object
#  15  YearBuilt      8205 non-null   object
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
Isi = {'Car' : '2.0', 'BuildingArea' :'200.000.00', 'YearBuilt' : '1990', 'CouncilArea' : 'Yarra'}

# %%
df.fillna(Isi, inplace=True)
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG      Date Distance    Postcode  ...  Bathroom  Car   Landsize  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  object
#  9   Postcode       13580 non-null  object
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13580 non-null  object
#  13  Landsize       13580 non-null  object
#  14  BuildingArea   13580 non-null  object
#  15  YearBuilt      13580 non-null  object
#  16  CouncilArea    13580 non-null  object
# ...

# %%
df.to_csv('Data/melb_dataEdit')

# %%
df = pd.read_csv('Data/melb_dataEdit', index_col = 'Unnamed: 0')
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG      Date Distance    Postcode  ...  Bathroom  Car   Landsize  \
# ...

# %%
df.drop(df.index[1500:13578], inplace = True)
df
# Out:
#           Suburb           Address  Rooms Type      Price Method    SellerG  \
# 0     Abbotsford      85 Turner St      2    h  1480000.0      S     Biggin
# 1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S     Biggin
# 2     Abbotsford      5 Charles St      3    h  1465000.0     SP     Biggin
# 3     Abbotsford  40 Federation La      3    h   850000.0     PI     Biggin
# 4     Abbotsford       55a Park St      4    h  1600000.0     VB     Nelson
# ...          ...               ...    ...  ...        ...    ...        ...
# 1495     Bulleen   1/7 Westwood Dr      3    u   812500.0      S      Barry
# 1496     Bulleen     14 Collins St      3    h   990000.0     PI      Barry
# 1497     Bulleen       4 Graeme Ct      4    h  1244000.0     PI  Fletchers
# 1498     Bulleen       19 Barak St      4    h  1100000.0     PI      Barry
# 1499     Bulleen  13 Birrarrung Ct      4    h  1475000.0     VB      Barry
#
# ...

# %% [markdown]
# Pada data transformasi ini saya menggunakan IMPUTASI NILAI SUKA-SUKA karena menurut saya imputasi ini sangat mudah untuk mengisi data null pada berbagai kolom yang masih terdapat data null. Hanya saja Imputasi ini kurang efektif dalam mengolah data yang sebenarnya karena kisaran untuk imputasi nilai suka- suka low range(sekitar 1-100 data saja).
